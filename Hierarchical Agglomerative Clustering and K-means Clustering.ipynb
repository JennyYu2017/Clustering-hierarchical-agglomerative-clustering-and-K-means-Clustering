# %% [markdown]
# ML:Hierarchical Agglomerative Clustering and K-means Clustering
# By Jenny YU

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
import math

# %%
data= pd.read_csv('dataset1.csv') 
data1= pd.DataFrame(data)


data= pd.read_csv('dataset2.csv') 
data2= pd.DataFrame(data)

# %% [markdown]
# # Load Training and Testing Dataset

# %%
print(data1.shape)
print(data1.head())
plt.scatter(data1.iloc[:,0],data1.iloc[:,1],s=2)
plt.xlabel('x')
plt.ylabel('y')
plt.legend('')
plt.title('Plot of data points from dataset1')
plt.show()
# Out:
# (3499, 2)
#    8.228429240780527065e-01   1.135491058107753304e+00
# 0                  1.292526                   1.600180
# 1                  0.869815                   1.370494
# 2                  2.097264                   1.710771
# 3                  2.024974                   3.001641
# 4                  1.799584                   0.174340

# %%
from mpl_toolkits import mplot3d


print(data2.shape)
print(data2.head())

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(data2.iloc[:,0],data2.iloc[:,1],data2.iloc[:,2],s=2)
plt.title('Plot of data points from dataset2')
# Out:
# (14800, 3)
#    -6.126607425458740153e+00   1.764511299313616988e+01  \
# 0                   5.602577                   5.034192
# 1                   2.179934                   9.876991
# 2                   6.088796                  16.889159
# 3                   6.436043                   1.070221
# 4                  -0.798785                   6.267833
#
#     6.095543727848264481e+00
# 0                 -10.091931
# 1                   7.160241
# 2                  -1.150638
# 3                   1.176709
# 4                   7.851932
# Text(0.5, 0.92, 'Plot of data points from dataset2')

# %%
#change data into list
X1 = list(data1.values)
X2 = list(data2.values)
colors= ["r", "g", "c", "b", "k","y","m","b"]
print(len(X1))
# Out:
# 3499

# %% [markdown]
# # Impletment Lloyd’s algorithm (k-means)
# reference：http://madhugnadig.com/articles/machine-learning/2017/03/04/implementing-k-means-clustering-from-scratch-in-python.html

# %% [markdown]
# # K-means clustering with uniform random initialization

# %%
# K-means clustering with uniform random initialization and K=2，3，4，5，6,7,8

class K_Means_2:
    
    def __init__(self, k=2, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        t=random.sample(range(len(data)),k)
        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = data[t[i]]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
#                 distances = [math.dist(featureset,self.centroids[centroid]) for centroid in self.centroids]

                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

    
#######################    
class K_Means_3:
    
    def __init__(self, k=3, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        t=random.sample(range(len(data)),k)
        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = data[t[i]]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification
    
    
#######################    
class K_Means_4:
    
    def __init__(self, k=4, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        t=random.sample(range(len(data)),k)
        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = data[t[i]]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

#######################    
class K_Means_5:
    
    def __init__(self, k=5, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        t=random.sample(range(len(data)),k)
        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = data[t[i]]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification
#######################    
class K_Means_6:
    
    def __init__(self, k=6, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        t=random.sample(range(len(data)),k)
        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = data[t[i]]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

####################### 

class K_Means_7:
    
    def __init__(self, k=7, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        t=random.sample(range(len(data)),k)
        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = data[t[i]]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

####################### 
class K_Means_8:
    
    def __init__(self, k=8, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        t=random.sample(range(len(data)),k)
        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = data[t[i]]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

# %%
#plot the clustering for 3D data

def plot3D(classifications, centroids):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    for classification in classifications:
        color = colors[classification]
        for featureset in model.classifications[classification]:
            ax.scatter(featureset[0], featureset[1], featureset[2], marker="x", color=color, s=2, linewidths=5)
   
    for centroid in model.centroids:
        ax.scatter(model.centroids[centroid][0], model.centroids[centroid][1], model.centroids[centroid][2],
                marker="o", color="k", s=10, linewidths=5)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Plot of Clustering from dataset2')
    return plt.show()



#    ax.scatter(x,y,z, marker=colormap[kmeans.labels_], s=40)

# %%
#plot the clustering for 2D data
def plot(classifications, centroids):
    for classification in classifications:
        color = colors[classification]
        for featureset in model.classifications[classification]:
            plt.scatter(featureset[0], featureset[1], marker="x", color=color, s=2, linewidths=5)
        
    for centroid in model.centroids:
        plt.scatter(model.centroids[centroid][0], model.centroids[centroid][1],
                marker="o", color="k", s=10, linewidths=5)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Plot of Clustering from dataset1')
    return plt.show()

# %% [markdown]
# # Random Intilization on Dataset1

# %%
#Impletment intitalization with k=2
centers={}
objective=[]
for i in range(3):
    model = K_Means_2()
    model.fit(X1)
    centers[i]= model.centroids
    plot(model.classifications,model.centroids)
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)

o=objective.index(min(objective))
center=centers[o+1]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([1.278888  , 0.35607492]), 1: array([-1.64789451, -0.63133547])}
# {0: array([-1.38917519,  0.79643229]), 1: array([ 0.67473349, -1.97902848])}
# {0: array([-6.13334333,  1.99220982]), 1: array([ 0.32292871, -0.64970595])}
# [7412.793735221456, 7406.8256595842695, 6209.905015969663]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-209fd1ff0698> in <module>
#      20
#      21 o=objective.index(min(objective))
# ---> 22 center=centers[o+1]
#      23 ob=objective[o]
#      24
#
# KeyError: 3

# %%
#Impletment intitalization with k=3
centers={}
objective=[]
for i in range(3):
    model = K_Means_3()
    model.fit(X1)
    centers[i]= model.centroids
    plot(model.classifications,model.centroids)
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)
# Out:
# {0: array([-6.1400055 ,  1.99312804]), 1: array([0.91661036, 1.01599778]), 2: array([-0.01828141, -1.60126367])}
# {0: array([-6.1400055 ,  1.99312804]), 1: array([-0.01722297, -1.60086933]), 2: array([0.91561326, 1.01770408])}
# {0: array([-6.1400055 ,  1.99312804]), 1: array([0.91561326, 1.01770408]), 2: array([-0.01722297, -1.60086933])}
# [4668.191531822341, 4668.193610948364, 4668.193610948364]

# %%
# Out:
# {0: array([ 0.85504765, -2.18212727]), 1: array([-1.18762253, -0.62908924]), 2: array([1.122322  , 1.05228978]), 3: array([-6.27968808,  2.0234607 ])}
# {0: array([ 0.85388412, -2.18041292]), 1: array([-1.18827255, -0.6277155 ]), 2: array([-6.27968808,  2.0234607 ]), 3: array([1.12242913, 1.05392904])}
# {0: array([ 0.85886385, -2.18493207]), 1: array([-1.18338742, -0.63241815]), 2: array([1.122322  , 1.05228978]), 3: array([-6.27968808,  2.0234607 ])}
# [3658.1422828322584, 3658.1629863548565, 3657.9574054318323]
# {0: array([ 0.85886385, -2.18493207]), 1: array([-1.18338742, -0.63241815]), 2: array([1.122322  , 1.05228978]), 3: array([-6.27968808,  2.0234607 ])} 3657.9574054318323

# %%
#Impletment intitalization with k=5
centers={}
objective=[]
for i in range(3):
    model = K_Means_5()
    model.fit(X1)
    centers[i]= model.centroids
    plot(model.classifications,model.centroids)
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)


o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([ 0.66400169, -1.13227937]), 1: array([ 0.9129025 , -2.86970624]), 2: array([-1.3505066, -0.5862859]), 3: array([1.14652624, 1.22110457]), 4: array([-6.29365994,  2.02272976])}
# {0: array([-6.29365994,  2.02272976]), 1: array([ 0.66400169, -1.13227937]), 2: array([ 0.9129025 , -2.86970624]), 3: array([-1.3505066, -0.5862859]), 4: array([1.14652624, 1.22110457])}
# {0: array([-6.29365994,  2.02272976]), 1: array([1.13656581, 1.19361332]), 2: array([-1.32258955, -0.59407437]), 3: array([ 0.88223319, -2.95277733]), 4: array([ 0.73011411, -1.23055509])}
# [3350.422093781471, 3350.422093781471, 3350.467479076549]
# {0: array([ 0.66400169, -1.13227937]), 1: array([ 0.9129025 , -2.86970624]), 2: array([-1.3505066, -0.5862859]), 3: array([1.14652624, 1.22110457]), 4: array([-6.29365994,  2.02272976])} 3350.422093781471

# %%
#Impletment intitalization with k=6
centers={}
objective=[]
for i in range(3):
    model = K_Means_6()
    model.fit(X1)
    centers[i]= model.centroids
    plot(model.classifications,model.centroids)
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)


o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([ 0.79386966, -0.38296064]), 1: array([1.2638728, 1.431511 ]), 2: array([-1.81988944,  0.08143089]), 3: array([ 0.98930322, -2.63500936]), 4: array([-6.4033543 ,  2.02918599]), 5: array([-0.73527906, -1.34408653])}
# {0: array([ 0.89408698, -2.85052096]), 1: array([-4.62629755,  2.00886487]), 2: array([-7.47402096,  1.98830667]), 3: array([1.14576636, 1.23001757]), 4: array([ 0.76304048, -1.08033676]), 5: array([-1.2425286 , -0.72441746])}
# {0: array([ 0.79093664, -0.35781743]), 1: array([-1.8231761 ,  0.08097461]), 2: array([ 0.99225505, -2.62663473]), 3: array([-0.7334621 , -1.34421783]), 4: array([-6.4033543 ,  2.02918599]), 5: array([1.26694618, 1.44321998])}
# [3140.15666988268, 3108.3989806114246, 3140.1876623449607]
# {0: array([ 0.89408698, -2.85052096]), 1: array([-4.62629755,  2.00886487]), 2: array([-7.47402096,  1.98830667]), 3: array([1.14576636, 1.23001757]), 4: array([ 0.76304048, -1.08033676]), 5: array([-1.2425286 , -0.72441746])} 3108.3989806114246

# %%
#Impletment intitalization with k=7
centers={}
objective=[]
for i in range(3):
    model = K_Means_7()
    model.fit(X1)
    centers[i]= model.centroids
    plot(model.classifications,model.centroids)
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)


o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([1.55901471, 1.60902265]), 1: array([-1.29596537, -0.79086857]), 2: array([ 0.78629655, -1.5181034 ]), 3: array([ 0.95020287, -3.15630603]), 4: array([-7.47402096,  1.98830667]), 5: array([0.51646499, 0.49043121]), 6: array([-4.62629755,  2.00886487])}
# {0: array([0.57989021, 0.4864736 ]), 1: array([ 0.95882741, -1.48240549]), 2: array([-0.95614238, -1.18000371]), 3: array([-6.44181495,  2.03424434]), 4: array([1.55689538, 1.65174991]), 5: array([-2.08316479,  0.36573509]), 6: array([ 0.92809756, -3.14276908])}
# {0: array([-0.95614238, -1.18000371]), 1: array([0.57989021, 0.4864736 ]), 2: array([ 0.95882741, -1.48240549]), 3: array([-2.08316479,  0.36573509]), 4: array([ 0.92809756, -3.14276908]), 5: array([1.55689538, 1.65174991]), 6: array([-6.44181495,  2.03424434])}
# [2873.054988983908, 2918.5138829759994, 2918.5138829759994]
# ...

# %%
#Impletment intitalization with k=8
centers={}
objective=[]
for i in range(3):
    model = K_Means_8()
    model.fit(X1)
    centers[i]= model.centroids
    plot(model.classifications,model.centroids)
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)


o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([ 0.95124915, -3.38976189]), 1: array([ 1.03519253, -0.47918455]), 2: array([ 0.85756715, -1.91368314]), 3: array([-0.99491696, -1.12961087]), 4: array([1.63077278, 1.66255838]), 5: array([0.41470233, 0.79497266]), 6: array([-6.45145646,  2.03809191]), 7: array([-2.19411192,  0.43885953])}
# {0: array([-0.72468805, -1.37864282]), 1: array([0.58969743, 0.49359699]), 2: array([-7.85905622,  1.95356112]), 3: array([-5.13637522,  2.0732653 ]), 4: array([-1.71781634, -0.14742063]), 5: array([ 1.02877897, -1.4834055 ]), 6: array([1.55899403, 1.65425638]), 7: array([ 0.94725737, -3.16285264])}
# {0: array([ 0.94809342, -3.43478508]), 1: array([0.38927782, 0.63421735]), 2: array([ 0.84388053, -2.00427264]), 3: array([ 1.06837999, -0.70123419]), 4: array([1.55568067, 1.60310394]), 5: array([-1.00957312, -1.10544483]), 6: array([-6.45648181,  2.03915459]), 7: array([-2.25645669,  0.48662895])}
# [2806.5064455309166, 2665.4739353274167, 2803.7774700264276]
# ...

# %%
K=[2,3,4,5,6,7,8]
cost=[6209.832355968957,4668.191531822341,3657.9574054318323,3350.422093781471,3108.3989806114246,2873.054988983908,2665.4739353274167]

plt.plot(K, cost, marker='o' )
plt.xlabel("K Values")
plt.ylabel("Cost")
plt.title("Cost vs K Values")
plt.show()

# %% [markdown]
# # Random Intilization on Dataset2

# %%
#Implement clustering on data2 when k=2
centers={}
objective=[]
for i in range(3):
    model = K_Means_2()
    model.fit(X2)
    centers[i]= model.centroids
    plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)
    
print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([ 4.94507044, 12.07848011,  4.42197864]), 1: array([-2.57471855, 12.24042087, -3.19180874])}
# {0: array([ 4.94507044, 12.07848011,  4.42197864]), 1: array([-2.57471855, 12.24042087, -3.19180874])}
# {0: array([ 6.52411047, 10.50478062,  0.42708187]), 1: array([-2.30855094, 13.46786832,  1.55779906])}
# [110982.40397782162, 110982.40397782162, 115949.84586647282]
# {0: array([ 4.94507044, 12.07848011,  4.42197864]), 1: array([-2.57471855, 12.24042087, -3.19180874])} 110982.40397782162

# %%
#Impletment intitalization with k=3 on Dataset 2
centers={}
objective=[]
for i in range(3):
    model = K_Means_3()
    model.fit(X2)
    centers[i]= model.centroids
    plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)
# Out:
# {0: array([-1.84847215, 10.93532179, -6.19385401]), 1: array([ 6.56660127, 11.17961768,  2.40190125]), 2: array([-3.2254732 , 14.27415219,  3.63986834])}
# {0: array([ 6.23850327, 11.38812682,  2.73317437]), 1: array([-1.00997345, 11.50107871, -6.93615709]), 2: array([-4.17399439, 13.64814208,  2.4734979 ])}
# {0: array([-1.62048189, 12.6348862 , -4.90671823]), 1: array([ 7.55882709, 13.48668411,  5.52377812]), 2: array([ 1.13646055, 10.94352498,  3.87811299])}
# [99941.01867425957, 99823.29140589558, 103431.75627784058]

# %%
#Impletment intitalization with k=4 on Dataset 2
centers={}
objective=[]
for i in range(3):
    model = K_Means_4()
    model.fit(X2)
    centers[i]= model.centroids
    plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([ 2.72258161, 12.99385463, -5.34809203]), 1: array([4.06047569, 9.67413285, 6.34008276]), 2: array([-4.65900405, 13.63405933,  1.84882602]), 3: array([10.02970408, 13.15177519,  1.28329599])}
# {0: array([ 4.9423913 , 12.08425857, -5.66453121]), 1: array([ 3.98444166, 16.20456928,  5.75898361]), 2: array([4.59583395, 7.29485342, 5.85439375]), 3: array([-5.39864868, 12.27846381, -0.86763149])}
# {0: array([ 4.52680004, 13.09265053,  6.26567504]), 1: array([ 1.26899152, 14.97194963, -6.069517  ]), 2: array([ 7.22233962,  7.28673315, -2.86486934]), 3: array([-5.37349078, 11.6297629 ,  1.26163939])}
# [91133.27294707506, 87817.07191893898, 90306.51115372861]
# {0: array([ 4.9423913 , 12.08425857, -5.66453121]), 1: array([ 3.98444166, 16.20456928,  5.75898361]), 2: array([4.59583395, 7.29485342, 5.85439375]), 3: array([-5.39864868, 12.27846381, -0.86763149])} 87817.07191893898

# %%
#Impletment intitalization with k=5 on Dataset 2
centers={}
objective=[]
for i in range(3):
    model = K_Means_5()
    model.fit(X2)
    centers[i]= model.centroids
#     plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([ 2.89996749, 13.10396975,  7.34801505]), 1: array([ 2.55487502, 15.82168975, -5.87984506]), 2: array([-5.21960156, 12.45484186,  1.88817185]), 3: array([-0.03749061,  6.53628845, -6.82577554]), 4: array([ 8.61491384, 10.98060851,  2.0376082 ])}
# {0: array([-4.77990107, 15.68036679,  0.35506295]), 1: array([4.45154846, 7.37475766, 5.95636348]), 2: array([ 4.72606452, 16.16130411,  5.81906227]), 3: array([-5.41236744,  7.12985202, -2.58140019]), 4: array([ 5.43161212, 12.37081262, -5.32967475])}
# {0: array([ 8.24939671, 11.55223073, -1.39073144]), 1: array([ 4.14980938, 12.34906833,  7.0143798 ]), 2: array([-2.48992447,  6.67529757, -6.66381314]), 3: array([-1.54777192, 16.16718094, -5.58192576]), 4: array([-4.69793115, 12.48678577,  3.41014856])}
# [84098.5050899281, 82105.62896867534, 84018.80943122489]
# ...

# %%
#Impletment intitalization with k=6 on Dataset 2
centers={}
objective=[]
for i in range(3):
    model = K_Means_6()
    model.fit(X2)
    centers[i]= model.centroids
#     plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([ 8.55288543,  6.9035874 , -0.29820225]), 1: array([ 5.24625004, 15.99125835,  6.00743249]), 2: array([ 5.01004365, 15.26538262, -5.13729999]), 3: array([1.03852085, 7.81382851, 7.05894813]), 4: array([-4.08373081,  9.00677534, -5.1645267 ]), 5: array([-4.7770657 , 15.7746365 ,  1.92571781])}
# {0: array([-5.59172918,  8.51696415,  1.87559128]), 1: array([5.6168717 , 7.14973766, 5.80899227]), 2: array([ 2.1880918 ,  7.84809041, -7.49498117]), 3: array([ 1.90210939, 15.91564736,  6.69509439]), 4: array([-4.08751632, 16.18587467, -3.47689431]), 5: array([ 7.92609238, 14.83301532, -1.57789494])}
# {0: array([ 4.90792811, 16.24515939,  6.06809813]), 1: array([-4.66248102, 15.55590116,  2.46442872]), 2: array([3.91036624, 7.26481917, 6.7113543 ]), 3: array([-6.06411624,  6.89921127, -1.1600881 ]), 4: array([ 8.21002719, 11.24033055, -2.63960471]), 5: array([-0.09209072, 13.54109461, -6.95304574])}
# [76458.0865379195, 76284.5734243673, 76634.26190777744]
# ...

# %%
#Impletment intitalization with k=7 on Dataset 2
centers={}
objective=[]
for i in range(3):
    model = K_Means_7()
    model.fit(X2)
    centers[i]= model.centroids
#     plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([-6.08890739,  6.94069586, -1.12545836]), 1: array([4.38528455, 7.12470066, 6.50540671]), 2: array([-4.75049175, 15.13527917,  2.91805038]), 3: array([ 5.26590353,  7.00704795, -6.34547075]), 4: array([-1.27868724, 15.43159545, -6.18616075]), 5: array([ 3.53519814, 16.03622622,  6.99306587]), 6: array([ 8.43990815, 14.70321838, -0.48004163])}
# {0: array([2.29397248, 7.5839268 , 7.46372993]), 1: array([8.77068619, 7.11134744, 0.12406807]), 2: array([-3.39256074,  6.65197127, -5.87077305]), 3: array([ 5.04643436, 16.22026327,  6.0525462 ]), 4: array([ 5.99086971, 14.83747509, -4.68977286]), 5: array([-4.54950642, 13.61887279,  3.59409469]), 6: array([-4.02027766, 16.06264454, -4.62555152])}
# ...

# %%
#Impletment intitalization with k=8 on Dataset 2
centers={}
objective=[]
for i in range(3):
    model = K_Means_8()
    model.fit(X2)
    centers[i]= model.centroids
#     plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([-3.31232839, 15.82919861, -5.1640368 ]), 1: array([ 1.50291389,  7.48668682, -7.89035784]), 2: array([ 4.95762357, 16.27960824,  6.39960485]), 3: array([2.40059372, 8.11807482, 7.52692713]), 4: array([ 7.14459861, 15.58824753, -3.3798352 ]), 5: array([8.80961855, 7.13177251, 1.30158398]), 6: array([-6.36263006,  7.42643924,  0.23335374]), 7: array([-4.11019538, 15.78355951,  3.89073155])}
# {0: array([-4.160667  , 15.65921465,  3.85242644]), 1: array([8.7891367 , 7.11857747, 1.49237414]), 2: array([ 1.90359431,  7.61012901, -7.87934556]), 3: array([-6.43557635,  7.32273629, -0.31160969]), 4: array([-3.2427991 , 15.88069693, -5.20959513]), 5: array([ 7.22292132, 15.62307624, -3.25507652]), 6: array([ 4.91762902, 16.23692533,  6.43727402]), 7: array([2.17305798, 8.06831267, 7.48969444])}
# ...

# %%
K=[2,3,4,5,6,7,8]
cost=[110982.40397782162,99823.29140589558,87817.07191893898,82105.62896867534,76284.5734243673,72241.42960991907,68212.15959196496]

plt.plot(K, cost, marker='o' )
plt.xlabel("K Values")
plt.ylabel("Cost")
plt.title("Cost vs K Values")
plt.show()

# %% [markdown]
# # Implement K-means clustering with K-means++

# %% [markdown]
# Define the cluster center using K-means++

# %%
import sys 

#define the cluster center using K-means++
def initialize(data, k): 
    ''' 
    initialized the centroids for K-means++ 
    inputs: 
        data - numpy array of data points having shape (200, 2) 
        k - number of clusters  
    '''
    ## initialize the centroids list and add 
    ## a randomly selected data point to the list 
    centroids = [] 
    centroids.append(data[np.random.randint(len(data))]) 
   
    ## compute remaining k - 1 centroids 
    for c_id in range(k - 1): 
          
        ## initialize a list to store distances of data 
        ## points from nearest centroid 
        dist = [] 
        for i in range(len(data)): 
            point = data[i] 
            d = sys.maxsize 
              
            ## compute distance of 'point' from each of the previously 
            ## selected centroid and store the minimum distance 
            for j in range(len(centroids)): 
                temp_dist = np.linalg.norm(point-centroids[j])
                d = min(d, temp_dist) 
            dist.append(d) 
              
        ## select data point with maximum distance as our next centroid 
        dist = np.array(dist) 
        next_centroid = data[np.argmax(dist)] 
        centroids.append(next_centroid) 
        dist = [] 
    return centroids

# %%
# K-means clustering with K-means++ uniform random initialization and K=2，3，4，5，6,7,8

class k_Means_2:
    
    def __init__(self, k=2, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter
    

    def fit(self,data):
        k = self.k
        centroids=initialize(data, k)

        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = centroids[i]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
#                 distances = [math.dist(featureset,self.centroids[centroid]) for centroid in self.centroids]

                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

    
#######################    
class k_Means_3:
    
    def __init__(self, k=3, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        centroids=initialize(data, k)
        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = data[i]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification
    
    
#######################    
class k_Means_4:
    
    def __init__(self, k=4, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        centroids=initialize(data, k)

        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = centroids[i]


        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

#######################    
class k_Means_5:
    
    def __init__(self, k=5, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        centroids=initialize(data, k)

        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = centroids[i]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification
#######################    
class k_Means_6:
    
    def __init__(self, k=6, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        centroids=initialize(data, k)

        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = centroids[i]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

####################### 

class k_Means_7:
    
    def __init__(self, k=7, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        centroids=initialize(data, k)

        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = centroids[i]

        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

####################### 
class k_Means_8:
    
    def __init__(self, k=8, tol=0.001, max_iter=50):
        self.k = k
        self.tol = tol
        self.max_iter = max_iter

    def fit(self,data):
        k = self.k
        centroids=initialize(data, k)

        self.centroids = {}
                                       
        for i in range(self.k):
            self.centroids[i] = centroids[i]
            
        for i in range(self.max_iter):
            self.classifications = {}

            for i in range(self.k):
                self.classifications[i] = []

            for featureset in data:
                distances = [np.linalg.norm(featureset-self.centroids[centroid]) for centroid in self.centroids]
                classification = distances.index(min(distances))
                self.classifications[classification].append(featureset)

            prev_centroids = dict(self.centroids)

            for classification in self.classifications:
                self.centroids[classification] = np.average(self.classifications[classification],axis=0)

            optimized = True

            for c in self.centroids:
                original_centroid = prev_centroids[c]
                current_centroid = self.centroids[c]
                if np.sum((current_centroid-original_centroid)/original_centroid*100.0) > self.tol:
#                   print(np.sum((current_centroid-original_centroid)/original_centroid*100.0))
                    optimized = False

            if optimized:
                break
                
            

    def predict(self,data):
        distances = [np.linalg.norm(data-self.centroids[centroid]) for centroid in self.centroids]
        classification = distances.index(min(distances))
        return classification

# %%
#Impletment intitalization with k=2
centers={}
objective=[]
for i in range(3):
    model = k_Means_2()
    model.fit(X1)
    centers[i]= model.centroids
    plot(model.classifications,model.centroids)
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([ 0.23245644, -0.59434336]), 1: array([-6.55753992,  2.03313077])}
# {0: array([ 0.14929265, -0.55096404]), 1: array([-6.82586423,  2.04283236])}
# {0: array([-0.05508929, -0.45243872]), 1: array([-7.48444088,  1.99875561])}
# [6240.859207317682, 6291.149323545659, 6501.5095419356985]
# {0: array([ 0.14929265, -0.55096404]), 1: array([-6.82586423,  2.04283236])} 6240.859207317682

# %%
#Impletment intitalization with k=3
centers={}
objective=[]
for i in range(3):
    model = k_Means_3()
    model.fit(X1)
    centers[i]= model.centroids
    plot(model.classifications,model.centroids)
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([0.91561326, 1.01770408]), 1: array([-6.1400055 ,  1.99312804]), 2: array([-0.01722297, -1.60086933])}
# {0: array([0.91561326, 1.01770408]), 1: array([-6.1400055 ,  1.99312804]), 2: array([-0.01722297, -1.60086933])}
# {0: array([0.91561326, 1.01770408]), 1: array([-6.1400055 ,  1.99312804]), 2: array([-0.01722297, -1.60086933])}
# [4668.193610948364, 4668.193610948364, 4668.193610948364]
# {0: array([0.91561326, 1.01770408]), 1: array([-6.1400055 ,  1.99312804]), 2: array([-0.01722297, -1.60086933])} 4668.193610948364

# %%
#Impletment intitalization with k=4
centers={}
objective=[]
for i in range(3):
    model = k_Means_4()
    model.fit(X1)
    centers[i]= model.centroids
    plot(model.classifications,model.centroids)
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
    print(model.centroids)

    
print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# {0: array([ 0.20945521, -1.1690136 ]), 1: array([-8.52024798,  1.88881048]), 2: array([-4.68794942,  1.70859897]), 3: array([1.41275536, 1.69435063])}
# {0: array([ 0.19444834, -0.28952204]), 1: array([-9.13201531,  1.88620161]), 2: array([ 1.0552351 , -3.25944419]), 3: array([-5.84953524,  2.05160743])}
# {0: array([0.91304262, 0.40121359]), 1: array([-8.83587502,  2.02448536]), 2: array([ 0.72871227, -2.57244839]), 3: array([-2.94807257,  0.30064365])}
# [4665.1465654392405, 5064.941648559548, 4837.816494670645]
# {0: array([ 0.20945521, -1.1690136 ]), 1: array([-8.52024798,  1.88881048]), 2: array([-4.68794942,  1.70859897]), 3: array([1.41275536, 1.69435063])} 4665.1465654392405

# %%
#Impletment intitalization with k=5
centers={}
objective=[]
for i in range(3):
    model = k_Means_5()
    model.fit(X1)
    centers[i]= model.centroids
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [3418.640541209198, 3416.277304839906, 3910.2871648911105]
# {0: array([1.12029283, 1.05259409]), 1: array([-7.47402096,  1.98830667]), 2: array([ 0.88097204, -2.19658947]), 3: array([-4.62629755,  2.00886487]), 4: array([-1.11480281, -0.72675074])} 3416.277304839906

# %%
#Impletment intitalization with k=6
centers={}
objective=[]
for i in range(3):
    model = k_Means_6()
    model.fit(X1)
    centers[i]= model.centroids
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [3310.0099435171824, 3306.4999165175022, 3309.2358638058113]
# {0: array([1.12284213, 1.05144249]), 1: array([-8.64507197,  1.91293242]), 2: array([ 0.88871407, -2.20186859]), 3: array([-4.04930265,  1.91234155]), 4: array([-1.09192718, -0.74728918]), 5: array([-6.28759033,  2.05373062])} 3306.4999165175022

# %%
#Impletment intitalization with k=7
centers={}
objective=[]
for i in range(3):
    model = k_Means_7()
    model.fit(X1)
    centers[i]= model.centroids
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [3001.59463039323, 3002.470883340549, 3002.497382576128]
# {0: array([ 0.80762258, -1.11808939]), 1: array([-8.60177869,  1.92067717]), 2: array([-3.95454153,  1.9112631 ]), 3: array([ 0.87579681, -2.88683982]), 4: array([1.14565062, 1.22391593]), 5: array([-1.20946556, -0.74524279]), 6: array([-6.20259452,  2.04521431])} 3001.59463039323

# %%
#Impletment intitalization with k=8
centers={}
objective=[]
for i in range(3):
    model = k_Means_8()
    model.fit(X1)
    centers[i]= model.centroids
    
    d=0
    for x in X1:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [2788.318535941548, 2785.330323119596, 2763.4090285406164]
# {0: array([ 0.78177286, -1.5295425 ]), 1: array([-8.61247058,  1.9144126 ]), 2: array([-4.06261045,  1.94451412]), 3: array([1.55063031, 1.63591348]), 4: array([ 0.95754397, -3.16782901]), 5: array([-1.28470286, -0.79787038]), 6: array([-6.25843602,  2.05068051]), 7: array([0.55220048, 0.48069632])} 2763.4090285406164

# %%
#Plot of cost vs K values for dataset 1
K=[2,3,4,5,6,7,8]

costR=[6209.832355968957,4668.191531822341,3657.9574054318323,3350.422093781471,3108.3989806114246,2873.054988983908,2665.4739353274167]
costK=[6240.859207317682,4668.193610948364,4370.972590094201,3416.277304839906,3306.4999165175022,3001.59463039323,2763.4090285406164]



fig, ax = plt.subplots()
ax.set_xlabel("Values of K")
ax.set_ylabel("Cost")
ax.set_title("Cost vs K Values with Different Initialization ")
ax.plot(K, costR, marker='o', label="Random")
ax.plot(K, costK, marker='o', label="K-means++")
ax.legend()
plt.show()

# %%
#Impletment intitalization with k=2
centers={}
objective=[]
for i in range(3):
    model = k_Means_2()
    model.fit(X2)
    centers[i]= model.centroids
    plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [113024.90162835439, 113245.41444000007, 113596.07161468198]
# {0: array([-1.98113649, 11.1126845 , -1.55854035]), 1: array([ 5.88467068, 13.37890993,  4.15060248])} 113024.90162835439

# %%
#Impletment intitalization with k=3
centers={}
objective=[]
for i in range(3):
    model = k_Means_3()
    model.fit(X2)
    centers[i]= model.centroids
    plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [107868.39025057983, 107868.39025057983, 107868.39025057983]
# {0: array([ 1.60218287,  6.85937249, -6.8568597 ]), 1: array([ 0.42154983, 10.88483074,  5.33466409]), 2: array([ 3.20938455, 15.79708536, -1.64773927])} 107868.39025057983

# %%
#Impletment intitalization with k=4
centers={}
objective=[]
for i in range(3):
    model = k_Means_4()
    model.fit(X2)
    centers[i]= model.centroids
    plot3D(model.classifications,model.centroids)
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [91758.65678305239, 90516.83593471644, 87822.6787044601]
# {0: array([ 3.96061476, 16.18515217,  5.78287816]), 1: array([-5.41156203, 12.2393597 , -0.73175268]), 2: array([ 4.80677932, 12.12489598, -5.73679169]), 3: array([4.79261602, 7.28528499, 5.75994562])} 87822.6787044601

# %%
#Impletment intitalization with k=5
centers={}
objective=[]
for i in range(3):
    model = k_Means_5()
    model.fit(X2)
    centers[i]= model.centroids
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [81686.43648048212, 81543.52457099213, 81344.36683229603]
# {0: array([-5.72775448, 12.51056003,  0.75694141]), 1: array([3.99984536, 6.93902125, 6.51716217]), 2: array([-0.09092273, 11.58618485, -7.32047186]), 3: array([ 3.13604792, 16.1632771 ,  6.58035662]), 4: array([ 8.35285049, 12.71023338, -1.69998426])} 81344.36683229603

# %%
#Impletment intitalization with k=6
centers={}
objective=[]
for i in range(3):
    model = k_Means_6()
    model.fit(X2)
    centers[i]= model.centroids
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [76564.31644718288, 76310.05802688542, 76451.08503912404]
# {0: array([ 8.11255227, 14.83752249, -0.88465447]), 1: array([-5.75326526,  8.43818707,  1.52539409]), 2: array([-3.82767035, 16.18309106, -3.79292614]), 3: array([5.36074394, 7.14804221, 6.05243811]), 4: array([ 2.7138861 ,  8.0051896 , -7.34390715]), 5: array([ 1.44986179, 15.91498776,  6.65801939])} 76310.05802688542

# %%
#Impletment intitalization with k=7
centers={}
objective=[]
for i in range(3):
    model = k_Means_7()
    model.fit(X2)
    centers[i]= model.centroids
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [72178.49362543244, 72228.81956094428, 72271.87832768305]
# {0: array([ 6.08489439, 15.95220125, -4.12604841]), 1: array([2.45120891, 8.28152995, 7.46892179]), 2: array([ 4.02888429, 16.40496477,  6.33653028]), 3: array([-6.23174414,  7.50382712,  0.94292179]), 4: array([-5.01712028, 16.14911005, -0.21674257]), 5: array([8.84685507, 7.5245297 , 0.77253859]), 6: array([ 0.04585482,  8.79826804, -7.75036264])} 72178.49362543244

# %%
#Impletment intitalization with k=8
centers={}
objective=[]
for i in range(3):
    model = k_Means_8()
    model.fit(X2)
    centers[i]= model.centroids
    
    d=0
    for x in X2:
        classification=model.predict(x) 
        d=d+np.linalg.norm(x-model.centroids[classification])
        
    objective.append(d)
#     print(model.centroids)

print(objective)

o=objective.index(min(objective))
center=centers[o]
ob=objective[o]

print(center, ob)
# Out:
# [68476.1549707035, 68217.60712368766, 68244.39175026248]
# {0: array([-4.02780075, 15.74114469,  3.99515142]), 1: array([ 7.03536048, 15.59100044, -3.5026522 ]), 2: array([8.81974951, 7.10924461, 1.03350996]), 3: array([ 5.01695411, 16.27543525,  6.35832426]), 4: array([-6.35028933,  7.41716784,  0.36318389]), 5: array([-3.47691415, 15.89374664, -5.0336544 ]), 6: array([2.54326574, 8.11100759, 7.53139943]), 7: array([ 1.20626167,  7.53451436, -7.9145875 ])} 68217.60712368766

# %%
K=[2,3,4,5,6,7,8]
costK=[110982.40397782162,99823.29140589558,87817.07191893898,82105.62896867534,76284.5734243673,72241.42960991907,68212.15959196496]

costR=[113024.90162835439,107868.39025057983,87822.6787044601,81344.36683229603,76310.05802688542,72178.49362543244,72178.49362543244]

fig, ax = plt.subplots()
ax.set_xlabel("Values of K")
ax.set_ylabel("Cost")
ax.set_title("Cost vs K Values with Different Initialization ")
ax.plot(K, costR, marker='o', label="Random")
ax.plot(K, costK, marker='o', label="K-means++")
ax.legend()
plt.show()

# %% [markdown]
# # Implement Hierarchical agglomerative clustering

# %% [markdown]
# #Experiment on Dataset1

# %%
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):
    
    # Create linkage matrix and then plot the dendrogram
    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    # for any child with index < n_samples, it is a sample. 
    # for any child with a larger index, it is a node in the tree
    
    for i, merge in enumerate(model.children_):
        # merge[0], merge[1] are the children of node i in the tree.
        
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)
    print(linkage_matrix.shape)
    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)
    

model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, affinity='euclidean',linkage='single')


model = model.fit(data1)
print(model.n_leaves_)

plt.title('Hierarchical Clustering Dendrogram Based on Single Linkage with Euclidean distance')
# plot the top 10 levels of the dendrogram
plot_dendrogram(model, truncate_mode='level', p=10)
plt.xlabel("Number of points in node")
plt.ylabel("Dissimilarity between two child nodes")
plt.xticks(rotation=45)
plt.show()
# Out:
# 3499
# (3498, 4)

# %%
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, affinity='euclidean',linkage='average')


model = model.fit(data1)
print(model.n_leaves_)

plt.title('Hierarchical Clustering Dendrogram Based on Average Linkage with Euclidean distance')
# plot the top 10 levels of the dendrogram
plot_dendrogram(model, truncate_mode='level', p=5)
plt.xlabel("Number of points in node")
plt.ylabel("Dissimilarity between two child nodes")
plt.xticks(rotation=90)
plt.show()
# Out:
# 3499
# (3498, 4)

# %%
#Experiment on Dataset2

# %%
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, affinity='euclidean',linkage='single')


model = model.fit(data2)
print(model.n_leaves_)

plt.title('Hierarchical Clustering Dendrogram Based on Single Linkage with Euclidean distance')
# plot the top 10 levels of the dendrogram
plot_dendrogram(model, truncate_mode='level', p=8)
plt.xlabel("Number of points in node")
plt.ylabel("Dissimilarity between two child nodes")
plt.xticks(rotation=45)
plt.show()
# Out:
# 14800
# (14799, 4)

# %%
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, affinity='euclidean',linkage='average')


model = model.fit(data2)
print(model.n_leaves_)

plt.title('Hierarchical Clustering Dendrogram Based on Single Linkage with Euclidean distance')
plot_dendrogram(model, truncate_mode='level', p=5)
plt.xlabel("Number of points in node")
plt.ylabel("Dissimilarity between two child nodes")
plt.xticks(rotation=90)
plt.show()
# Out:
# 14800
# (14799, 4)
